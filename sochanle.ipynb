# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904394-droid/sochanle.ipynb/blob/main/sochanle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
daysonguyen=input("Nhap day so nguyen:")
danhsachdayso=daysonguyen.split()
danhsachchuoiso = list(map(int, danhsachdayso))
sochan=0
sole=0
for so in danhsachchuoiso:
   if so %2==0:
      sochan=sochan+so
   else :
      sole=sole+so
print("Tong so chan:",sochan)
print("Tong so le:",sole)
# Out:
# Nhap day so nguyen:5 8 4 3
# Tong so chan: 12
# Tong so le: 8
